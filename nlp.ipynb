# %% [markdown]
# <a href="https://colab.research.google.com/github/JeetInTech/Training/blob/main/nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/refs/heads/main/youtubesample.csv", encoding='utf-8')

# %%
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df.iloc[1:9:1]
# Out:
#       video_id trending_date  \
# 1  2yCp-Dj5-7c      17.16.12
# 2  H00djJq68VE      17.27.12
# 3  oTObwUiXdYY      17.19.11
# 4  yvicqMrAHvQ      18.05.02
# 5  qDAxDcjgn-8      17.18.11
# 6  kton-qrKNLc      18.08.03
# 7  oRArmtMA9AI      18.15.03
# 8  84p7f-Rh-RY      17.21.12
#
#                                                title  \
# 1  Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2  Panettone (Italian Christmas Bread) - Food Wishes
# 3  7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4            Turkish Airlines - 5 Senses with Dr. Oz
# 5             Taylor Swift - Reputation ALBUM REVIEW
# 6                        Meghan Trainor - No Excuses
# 7            Marshmello - FLY (Official Music Video)
# 8  Kate Winslet On Working With Woody Allen | Los...
#
#                              channel_title  category_id  \
# 1  Watch What Happens Live with Andy Cohen           24
# 2                              Food Wishes           26
# ...

# %%
#iloc
#df.illoc[start :stop :step]

# %%
df.loc[3050 : 2636: 1]
# Out:
# Empty DataFrame
# Columns: [video_id, trending_date, title, channel_title, category_id, publish_time, tags, views, likes, dislikes, comment_count, thumbnail_link, comments_disabled, ratings_disabled, video_error_or_removed, description, Genre]
# Index: []

# %%
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df.iloc[5:9:1]
# Out:
#       video_id trending_date  \
# 5  qDAxDcjgn-8      17.18.11
# 6  kton-qrKNLc      18.08.03
# 7  oRArmtMA9AI      18.15.03
# 8  84p7f-Rh-RY      17.21.12
#
#                                                title      channel_title  \
# 5             Taylor Swift - Reputation ALBUM REVIEW      theneedledrop
# 6                        Meghan Trainor - No Excuses  MeghanTrainorVEVO
# 7            Marshmello - FLY (Official Music Video)         Marshmello
# 8  Kate Winslet On Working With Woody Allen | Los...  Los Angeles Times
#
#    category_id              publish_time  \
# 5           10  2017-11-14T23:06:27.000Z
# 6           10  2018-03-01T13:00:05.000Z
# 7           10  2018-03-09T05:01:14.000Z
# 8           25  2017-12-16T23:19:59.000Z
#
#                                                 tags    views   likes  \
# 5  album|"review"|"music"|"reviews"|"indie"|"unde...   274155   10765
# 6  meghan trainor|"no excuses"|"no excuses offici...  8368595  261615
# ...

# %%
#data filteration

# %%
df[df['channel_title'] =="Marshmello"]
# Out:
#          video_id trending_date  \
# 7     oRArmtMA9AI      18.15.03
# 1651  oRArmtMA9AI      18.23.03
# 1740  oRArmtMA9AI      18.14.03
# 3239  oRArmtMA9AI      18.13.03
# 4632  2SJ0hgdciNE      18.05.06
#
#                                                   title channel_title  \
# 7               Marshmello - FLY (Official Music Video)    Marshmello
# 1651            Marshmello - FLY (Official Music Video)    Marshmello
# 1740            Marshmello - FLY (Official Music Video)    Marshmello
# 3239            Marshmello - FLY (Official Music Video)    Marshmello
# 4632  Marshmello x Juicy J - You Can Cry (Ft. James ...    Marshmello
#
#       category_id              publish_time  \
# 7              10  2018-03-09T05:01:14.000Z
# 1651           10  2018-03-09T05:01:14.000Z
# 1740           10  2018-03-09T05:01:14.000Z
# 3239           10  2018-03-09T05:01:14.000Z
# 4632           10  2018-05-30T14:00:00.000Z
#
# ...

# %%
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df[df['views'] >= 500000]
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 4     yvicqMrAHvQ      18.05.02
# 6     kton-qrKNLc      18.08.03
# 7     oRArmtMA9AI      18.15.03
# 9     Biex1XR_mpo      18.24.03
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# 6                           Meghan Trainor - No Excuses
# 7               Marshmello - FLY (Official Music Video)
# 9                50 Mums | 50 Kids | 1 Extra Chromosome
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
#find out those data which is having more than 5000 comments

# %%
df[df['comment_count']>= 5000]
# Out:
#          video_id trending_date  \
# 6     kton-qrKNLc      18.08.03
# 7     oRArmtMA9AI      18.15.03
# 10    RQm0nKoODo4      18.13.03
# 17    QBL8IRJ5yHU      18.04.06
# 18    wW4JB9tjlik      18.10.06
# ...           ...           ...
# 4977  uVcvhKTVZ8g      18.04.05
# 4980  tfREC-AkX20      18.14.04
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title      channel_title  \
# 6                           Meghan Trainor - No Excuses  MeghanTrainorVEVO
# 7               Marshmello - FLY (Official Music Video)         Marshmello
# 10             Take On Me in 20 Styles ft. Seth Everman   Ten Second Songs
# 17    Why I'm So Scared (being myself and crying too...      grav3yardgirl
# 18    24 HOUR BOX FORT PRISON ESCAPE ROOM!! 📦🚔 UNDER...          Papa Jake
# ...                                                 ...                ...
# ...

# %%
df[(df['comment_count'] >= 5000) & (df['channel_title'] == 'Marshmello')]
# Out:
#          video_id trending_date  \
# 7     oRArmtMA9AI      18.15.03
# 1651  oRArmtMA9AI      18.23.03
# 1740  oRArmtMA9AI      18.14.03
# 3239  oRArmtMA9AI      18.13.03
# 4632  2SJ0hgdciNE      18.05.06
#
#                                                   title channel_title  \
# 7               Marshmello - FLY (Official Music Video)    Marshmello
# 1651            Marshmello - FLY (Official Music Video)    Marshmello
# 1740            Marshmello - FLY (Official Music Video)    Marshmello
# 3239            Marshmello - FLY (Official Music Video)    Marshmello
# 4632  Marshmello x Juicy J - You Can Cry (Ft. James ...    Marshmello
#
#       category_id              publish_time  \
# 7              10  2018-03-09T05:01:14.000Z
# 1651           10  2018-03-09T05:01:14.000Z
# 1740           10  2018-03-09T05:01:14.000Z
# 3239           10  2018-03-09T05:01:14.000Z
# 4632           10  2018-05-30T14:00:00.000Z
#
# ...

# %% [markdown]
# 17th

# %%
pip install nltk

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/refs/heads/main/titanic_dataset.csv", encoding='utf-8')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Gender'] == 'male') & (df['Age'] > 50)].count()
# Out:
# PassengerId    47
# Survived       47
# Pclass         47
# Name           47
# Gender         47
# Age            47
# SibSp          47
# Parch          47
# Ticket         47
# Fare           47
# Cabin          20
# Embarked       47
# dtype: int64

# %%
df[(df['Gender'] == 'female') & (df['Survived'] == 1)].count()
# Out:
# PassengerId    233
# Survived       233
# Pclass         233
# Name           233
# Gender         233
# Age            197
# SibSp          233
# Parch          233
# Ticket         233
# Fare           233
# Cabin           91
# Embarked       231
# dtype: int64

# %%
df.loc[df['Age'] > 55, 'Fare'] = 500
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#update fare values of pclass 1 who have more than 4 SibSp to 1000 #>2 because >4 is not present
df.loc[(df['Pclass'] == 1) & (df['SibSp'] > 2), 'Fare'] = 1000
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#inc fair prices by 30% where gender is female and pclass is 1

# %%
df.loc[(df['Pclass'] == 1) & (df['Gender'] == 'female'), 'Fare']  *=1.3 #df['Fare']*1.3
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# NULL

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df.loc[df['Age'].isnull(),'Age']=29.69    #for filterring the null values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#fill null values in embark column

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df.loc[df['Embarked'].isnull(),'Embarked']= 'S'

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# WHEN WE HAVE OUTLIERS WE DHOULD USE MEDIAN WHEN WE DONT HAVE ONLY MEAN

# %% [markdown]
# OUTLIERS IMPACT THE MEAN VALUE

# %%
df.dropna(how='all', inplace=True)

# %%
df.iloc[:10, :3]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2

# %%
df.iloc[:10, :3]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2

# %%
df.loc[df['Gender'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[(df['Pclass'] == 3) & (df['Fare'].isnull()), 'Fare'] = 0

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Fare'].fillna(df['Fare'].median(), inplace=True)
# Out:
# <ipython-input-8-3212fbb9c169>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# <ipython-input-8-3212fbb9c169>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.iloc[5:11, 2:5]
# Out:
#     Pclass                                               Name  Gender
# 5        3                                   Moran, Mr. James    male
# 6        1                            McCarthy, Mr. Timothy J    male
# 7        3                     Palsson, Master. Gosta Leonard    male
# 8        3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female

# %%
df.loc[(df['Fare'] >= 50) & (df['Fare'] <= 100)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 34            35         0       1
# 35            36         0       1
# ..           ...       ...     ...
# 849          850         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Cabin'].fillna('Unknown', inplace=True)
# Out:
# <ipython-input-11-795aa4b57402>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cabin'].fillna('Unknown', inplace=True)

# %%
df.loc[(df['Embarked'] == 'S') & (df['Fare'] > 30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 6              7         0       1
# 13            14         0       3
# 23            24         1       1
# 25            26         1       3
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
if df['Cabin'].isnull().mean() > 0.7:
    df.drop('Cabin', axis=1, inplace=True)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.iloc[-5:]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare    Cabin Embarked
# 886    male  27.0      0      0      211536  13.00  Unknown        S
# 887  female  19.0      0      0      112053  30.00      B42        S
# 888  female  28.0      1      2  W./C. 6607  23.45  Unknown        S
# 889    male  26.0      0      0      111369  30.00     C148        C
# 890    male  32.0      0      0      370376   7.75  Unknown        Q

# %%
df.loc[(df['Survived'] == 1) & (df['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 23            24         1       1
# 31            32         1       1
# ..           ...       ...     ...
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  28.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ABOVE ARE THE 20 PRACTICE QUESTIONS

# %% [markdown]
# 18/01/2025 AD

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/refs/heads/main/youtubesample.csv", encoding='utf-8')

# %%
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df[df['title'].str.contains('INSTAGRAM')]
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 56    s4kX4R6T9ms      18.07.04
# 319   m8Dqg8iz5Fo      18.14.05
# 2927  oY9GVZKwBhI      18.01.05
# 3094  ms7t4CnjW1k      18.26.02
# 3281  oY9GVZKwBhI      18.08.05
#
#                                                   title channel_title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...   Sylvia Gani
# 56    VIRAL INSTAGRAM ONE-SWIPE EYESHADOW Review (fi...   heyitsfeiii
# 319   MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...   Sylvia Gani
# 2927          COPYING MADDIE ZIEGLER'S INSTAGRAM PHOTOS    Jess Conte
# 3094                          HOW I EDIT MY INSTAGRAMS!   FunForLouis
# 3281          COPYING MADDIE ZIEGLER'S INSTAGRAM PHOTOS    Jess Conte
#
#       category_id              publish_time  \
# 0              26  2018-04-30T00:18:19.000Z
# 56             26  2018-04-04T22:00:03.000Z
# 319            26  2018-04-30T00:18:19.000Z
# 2927           24  2018-04-26T00:55:12.000Z
# ...

# %%
#find data whih has 'GAMING' tags
df[df['tags'].str.contains('gaming')]
# Out:
#          video_id trending_date  \
# 60    AV1SWIPxxFM      18.25.05
# 429   UfKmSfgFxi8      18.27.05
# 548   MT7RQ0gu8ak      18.16.05
# 623   PV_GHHXy7Po      18.06.06
# 684   vDyYMcjf500      18.29.05
# 884   3tjHS7JRB4c      18.07.03
# 923   19QxOZU0zkQ      18.14.01
# 1085  r-3iathMo7o      18.23.05
# 1182  9WFf9XY5rME      18.31.03
# 1216  -kTWIm7m4Uw      18.08.06
# 1221  KrxDhokzEv4      17.03.12
# 1283  Yg8jdBLTtfo      18.07.06
# 1284  qD2yyikDcDw      18.07.05
# 1323  DbJ2s_g1oDc      17.18.11
# 1326  4tpIiSqyiLo      18.30.04
# 1524  1ZXWwIjQnHs      18.05.06
# 1631  wa9ZyarpM2U      17.01.12
# 1639  r-3iathMo7o      18.29.05
# 1770  ifkRhaEDzzo      17.18.12
# 1776  9WFf9XY5rME      18.25.03
# 1959  UfKmSfgFxi8      18.24.05
# 1970  XUIwpXq_jBo      18.08.03
# 2241  -kTWIm7m4Uw      18.03.06
# 2673  o3T_o4WM-n8      18.12.02
# 2756  UfKmSfgFxi8      18.16.05
# 2867  fi483E-A8P4      18.13.02
# 2919  Yg8jdBLTtfo      18.01.06
# 3023  XUIwpXq_jBo      18.10.03
# ...

# %%
df['title'] = df['title'].str.replace('INSTAGRAM', 'INSTA')

# %%
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0       MY INSTA FOLLOWERS PICK MY FULL FACE OF MAKEUP!
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df['title'] = df['title'].str.replace('MY', 'MINE')

# %%
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MINE INSTA FOLLOWERS PICK MINE FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df['title'] = df['title'].str.lower()

# %%
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     mine insta followers pick mine full face of ma...
# 1     does tiffany haddish think nene leakes is funn...
# 2     panettone (italian christmas bread) - food wishes
# 3     7.3 magnitude earthquake along iraq-iran borde...
# 4               turkish airlines - 5 senses with dr. oz
# ...                                                 ...
# 4995          red velvet 레드벨벳 '봐 (look)' dance practice
# 4996                   god of war – story trailer | ps4
# 4997  halsey - alone (audio) ft. big sean, stefflon don
# ...

# %%
df['title'] = df['title'].str[:11:1]

# %%
df
# Out:
#          video_id trending_date       title  \
# 0     m8Dqg8iz5Fo      18.09.05  mine insta
# 1     2yCp-Dj5-7c      17.16.12  does tiffa
# 2     H00djJq68VE      17.27.12  panettone
# 3     oTObwUiXdYY      17.19.11  7.3 magnit
# 4     yvicqMrAHvQ      18.05.02  turkish ai
# ...           ...           ...         ...
# 4995  bqFjyo7I8fY      18.01.03  red velvet
# 4996  K0u_kAWLJOA      18.25.01  god of war
# 4997  XGd1dq1BatM      18.19.03  halsey - a
# 4998  vGTTSdrV37U      18.04.04  camila cab
# 4999  DkeiKbqa02g      18.22.05  calvin har
#
#                                 channel_title  category_id  \
# 0                                 Sylvia Gani           26
# 1     Watch What Happens Live with Andy Cohen           24
# 2                                 Food Wishes           26
# 3                                        TIME           25
# 4                            Turkish Airlines           19
# ...                                       ...          ...
# ...

# %%
df['thumbnail_link'].str.split('/').str[4]
# Out:
# 0       m8Dqg8iz5Fo
# 1       2yCp-Dj5-7c
# 2       H00djJq68VE
# 3       oTObwUiXdYY
# 4       yvicqMrAHvQ
#            ...
# 4995    bqFjyo7I8fY
# 4996    K0u_kAWLJOA
# 4997    XGd1dq1BatM
# 4998    vGTTSdrV37U
# 4999    DkeiKbqa02g
# Name: thumbnail_link, Length: 5000, dtype: object
